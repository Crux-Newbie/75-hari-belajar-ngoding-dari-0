# %%
print("aku rawrasdasda")
# Out:
# aku rawrasdasda

# %%
tes = lambda x,y : x + y
print(f"hasil dari 42 + 8 adalah {tes(42,8)}")
# Out:
# hasil dari 42 + 8 adalah 50

# %%
hidung = ["hitam","legam","asolole"]
hidung [1] ="cihuy"
print(hidung)
# Out:
# ['hitam', 'cihuy', 'asolole']

# %%
angka = 9
if angka > 25:
    print ("cihuy")
elif angka < 15:
    print ("asolole")
else:
    print ("lah")
# Out:
# asolole

# %%
def pandawa (supersemar):
    return (f"kenalno, jenengku {supersemar}")
anak1 = pandawa ("arjuna")
anak2 = pandawa ("arjuni")
anak3 = pandawa ('arjuno')
print(anak2)
# Out:
# kenalno, jenengku arjuni

# %%
merk_motor = ("yamaha", "honda", "suzuran")
print (merk_motor)
