# %%
class kelasku:
    def __init__(self,nama,absen):
        self.nama = nama
        self.absen = absen 
    def guru(self):
        print(f"ayonima {self.nama} asolole {self.absen}")
asdasda = kelasku("jenal","12")
asdasda.guru()
# Out:
# ayonima jenal asolole 12
