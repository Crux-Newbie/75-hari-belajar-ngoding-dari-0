# %%
def device (punyaku):
    return (f"aku mempunyai banyak hal seperti {punyaku}")
isi1 = device ("sempak")
isi2 = device ("asolole")
print (isi1)
# Out:
# aku mempunyai banyak hal seperti sempak

# %%
makanan = lambda x : x ** 2
print(f"hasil dari 12 kuadrat adalah {makanan(12)}")
# Out:
# hasil dari 12 kuadrat adalah 144

# %%
daftar = ["ayam","ayem","asu"]
daftar [1] = "mentok"
print(daftar[2])
# Out:
# asu

# %%
fakta = ("indo lolot","negara jembut","cihuy")
print(fakta[2])
# Out:
# cihuy

# %%
angka = [4,6,2,5,67,8,3,3,5,34,5,5,23,2,0,3,1,34,5,5,7,3,]
print(angka)
# Out:
# [4, 6, 2, 5, 67, 8, 3, 3, 5, 34, 5, 5, 23, 2, 0, 3, 1, 34, 5, 5, 7, 3]

# %%
data_diri = {"nama" : "King jenal", "usia" : "old enough", "keahlian" : "do completely nothing"}
print(data_diri["keahlian"])
# Out:
# do completely nothing

# %%
hasil = {x + y for x in range (3) for y in range (5)}
print(hasil)
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
with open ("cheatsheet(1).txt","a") as file:
    file.write("\nselalu riang dan berwarna hitam")

# %%
kelas = input("kelas berapa kamu dek?")
print("oh ternyata kamu kelas " + kelas + " ya?")
# Out:
# oh ternyata kamu kelas 12 ya?

# %%
try:
    nama_buku = input("Bukunya apa mas namanya?")
    isinya = input("Intinya tentang apa mas?")
    
    with open  (nama_buku,"a")as f:
        f.write (f"{isinya}")

except Exception as a:
    print(f"salah bro, namanya {a}")
finally:
    print("cihuyyy")
# Out:
# cihuyyy
